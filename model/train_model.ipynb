# %%
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from tensorflow import keras
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
from custom_models import custom_model, old_model
from data_augmentation import DataAugmentation
from data_preprocessing import Preprocessing
from config import ConstantConfig, DatasetConfig
ENCODER = ConstantConfig().ENCODER
file_path = DatasetConfig().file_path

# %%
preprocessing = Preprocessing()
augmentation = DataAugmentation()
img_data = augmentation.process_data()
labels_train, labels_test, imgs_train, imgs_test = preprocessing.train_test_split(img_data)
model = old_model()
# Out:
# 100%|██████████| 204/204 [03:06<00:00,  1.09it/s]

# %%
batch_size = 64
epochs = 50
early_stopping = keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5)
steps_per_epoch = 5

# %%
model.fit(imgs_train, labels_train, batch_size=batch_size, epochs=epochs,
                       validation_data=(imgs_test, labels_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 646/646 [==============================] - 58s 88ms/step - loss: 1.9776 - accuracy: 0.4685 - val_loss: 1.3736 - val_accuracy: 0.6371
# Epoch 2/50
# 646/646 [==============================] - 57s 88ms/step - loss: 1.2479 - accuracy: 0.6593 - val_loss: 1.1659 - val_accuracy: 0.6858
# Epoch 3/50
# 646/646 [==============================] - 59s 92ms/step - loss: 1.0841 - accuracy: 0.7033 - val_loss: 1.0820 - val_accuracy: 0.7094
# Epoch 4/50
# 646/646 [==============================] - 58s 90ms/step - loss: 0.9686 - accuracy: 0.7338 - val_loss: 1.0234 - val_accuracy: 0.7170
# Epoch 5/50
# 646/646 [==============================] - 57s 89ms/step - loss: 0.8936 - accuracy: 0.7530 - val_loss: 0.9970 - val_accuracy: 0.7274
# Epoch 6/50
# 646/646 [==============================] - 58s 90ms/step - loss: 0.8290 - accuracy: 0.7735 - val_loss: 0.9551 - val_accuracy: 0.7440
# Epoch 7/50
# 646/646 [==============================] - 58s 90ms/step - loss: 0.7743 - accuracy: 0.7868 - val_loss: 0.9193 - val_accuracy: 0.7498
# Epoch 8/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.7258 - accuracy: 0.8000 - val_loss: 0.9338 - val_accuracy: 0.7484
# Epoch 9/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.6881 - accuracy: 0.8096 - val_loss: 0.8982 - val_accuracy: 0.7623
# Epoch 10/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.6489 - accuracy: 0.8204 - val_loss: 0.9216 - val_accuracy: 0.7583
# Epoch 11/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.6179 - accuracy: 0.8274 - val_loss: 0.8773 - val_accuracy: 0.7647
# Epoch 12/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.5913 - accuracy: 0.8342 - val_loss: 0.8944 - val_accuracy: 0.7628
# Epoch 13/50
# 646/646 [==============================] - 58s 90ms/step - loss: 0.5636 - accuracy: 0.8414 - val_loss: 0.8623 - val_accuracy: 0.7805
# Epoch 14/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.5323 - accuracy: 0.8499 - val_loss: 0.8996 - val_accuracy: 0.7657
# Epoch 15/50
# 646/646 [==============================] - 58s 89ms/step - loss: 0.5151 - accuracy: 0.8523 - val_loss: 0.8778 - val_accuracy: 0.7709
# Epoch 16/50
# 646/646 [==============================] - 59s 91ms/step - loss: 0.4914 - accuracy: 0.8588 - val_loss: 0.9030 - val_accuracy: 0.7661
# Epoch 17/50
# 646/646 [==============================] - 58s 89ms/step - loss: 0.4715 - accuracy: 0.8636 - val_loss: 0.8597 - val_accuracy: 0.7864
# Epoch 18/50
# 646/646 [==============================] - 58s 90ms/step - loss: 0.4619 - accuracy: 0.8676 - val_loss: 0.8522 - val_accuracy: 0.7834
# Epoch 19/50
# 646/646 [==============================] - 59s 92ms/step - loss: 0.4417 - accuracy: 0.8727 - val_loss: 0.8631 - val_accuracy: 0.7875
# Epoch 20/50
# 646/646 [==============================] - 57s 89ms/step - loss: 0.4278 - accuracy: 0.8750 - val_loss: 0.8528 - val_accuracy: 0.7845
# Epoch 21/50
# 646/646 [==============================] - 55s 84ms/step - loss: 0.4190 - accuracy: 0.8783 - val_loss: 0.8614 - val_accuracy: 0.7837
# Epoch 22/50
# 646/646 [==============================] - 54s 84ms/step - loss: 0.4033 - accuracy: 0.8829 - val_loss: 0.8933 - val_accuracy: 0.7804
# Epoch 23/50
# 646/646 [==============================] - 55s 86ms/step - loss: 0.3915 - accuracy: 0.8847 - val_loss: 0.8568 - val_accuracy: 0.7891
# Epoch 24/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3719 - accuracy: 0.8907 - val_loss: 0.8699 - val_accuracy: 0.7901
# Epoch 25/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3604 - accuracy: 0.8943 - val_loss: 0.8940 - val_accuracy: 0.7869
# Epoch 26/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3517 - accuracy: 0.8975 - val_loss: 0.8756 - val_accuracy: 0.7916
# Epoch 27/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3474 - accuracy: 0.8968 - val_loss: 0.8797 - val_accuracy: 0.7889
# Epoch 28/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3372 - accuracy: 0.8973 - val_loss: 0.8901 - val_accuracy: 0.7975
# Epoch 29/50
# 646/646 [==============================] - 56s 87ms/step - loss: 0.3247 - accuracy: 0.9028 - val_loss: 0.9058 - val_accuracy: 0.7890
# Epoch 30/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3215 - accuracy: 0.9026 - val_loss: 0.9135 - val_accuracy: 0.7875
# Epoch 31/50
# 646/646 [==============================] - 55s 85ms/step - loss: 0.3133 - accuracy: 0.9057 - val_loss: 0.9022 - val_accuracy: 0.7860
# Epoch 32/50
# 646/646 [==============================] - 56s 86ms/step - loss: 0.3060 - accuracy: 0.9081 - val_loss: 0.8953 - val_accuracy: 0.7960
# Epoch 33/50
# 646/646 [==============================] - 55s 86ms/step - loss: 0.2976 - accuracy: 0.9086 - val_loss: 0.9071 - val_accuracy: 0.7949

# %%
print(ENCODER.inverse[1])
plt.figure()
plt.imshow(img_data[1][0])
plt.grid(False)
plt.show()
# Out:
# ა

# %%
imgs = np.array([val for ob in img_data.values() for val in ob])

labels = []
for key, value in img_data.items():
    labels.extend([key]* len(value))
labels = np.array(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 imgs = np.array([val for ob in img_data.values() for val in ob])
#       3 labels = []
#       4 for key, value in img_data.items():
#
# NameError: name 'np' is not defined

# %%
imgs.shape, labels.shape
# Out:
# ((48625, 50, 50, 1), (48625,))

# %%
labels, imgs = shuffle(labels, imgs)
split = .75
labels_train = labels[:int(len(labels) * split)]
labels_test = labels[int(len(labels) * split):]

imgs_train = imgs[:int(len(imgs) * split)]
imgs_test = imgs[int(len(imgs) * split):]

# %%
model = custom_model()

# %%
batch_size = 16
epochs = 20
early_stopping = keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=2)

# %%
labels_train.shape
# Out:
# (36468,)

# %%
model.fit(imgs_train, labels_train, batch_size=batch_size, epochs=epochs, validation_data=(imgs_test, labels_test), callbacks=[early_stopping])
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model.fit(imgs_train, labels_train, batch_size=batch_size, epochs=epochs, validation_data=(imgs_test, labels_test), callbacks=[early_stopping])
#
# File c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filewklnuv21.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\training.py", line 1051, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\losses.py", line 1984, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\backend.py", line 5559, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 34) are incompatible

# %%
import numpy as np
labels_pred = np.argmax(model.predict(imgs_test), axis=1)
# Out:
# 228/228 [==============================] - 2s 8ms/step

# %%
cm = confusion_matrix(labels_test, labels_pred, labels=list(ENCODER.inverse.keys()))

# %%
plt.figure(figsize=(12,12))
sns.heatmap(cm, annot=True, cbar=False, cmap='Blues', xticklabels=list(ENCODER.keys()), yticklabels=list(ENCODER.keys()))
plt.show()

# %%
model.save('geomodel.model', save_format='h5')

# %%
keras.models.load_model('geomodel.model')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 keras.models.load_model('geomodel.model')
#
# File c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\saving\saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\annch\anaconda3\envs\ocr_env\lib\site-packages\tensorflow\python\lib\io\file_io.py:703, in is_directory_v2(path)
#     694 """Returns whether the path is a directory or not.
#     695
#     696 Args:
#    (...)
#     700   True, if the path is a directory; False otherwise
#     701 """
#     702 try:
# --> 703   return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704 except errors.OpError:
#     705   return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 36: invalid continuation byte

# %%
import cv2
def test_model(file_path):
    img_vector = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8),  cv2.IMREAD_GRAYSCALE).astype("float32")
    img_vector = cv2.resize(img_vector, (50, 50), interpolation = cv2.INTER_AREA) / 255
    img_vector = np.expand_dims(img_vector,-1)
    print(np.array([img_vector]).shape)
    pred_letter = np.argmax(model.predict(np.array([img_vector])), axis=-1)
    pred_letter = ENCODER.inverse[pred_letter[0]]
    return pred_letter

test_model('result\word0_0-1_6.png')
# Out:
# (1, 50, 50, 1)
# 1/1 [==============================] - 0s 22ms/step
# 'შ'

# %%
from datasets import load_dataset

dataset = load_dataset("AnaChikashua/handwriting", split='train')
# Out:
# Downloading readme:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# Downloading and preparing dataset imagefolder/AnaChikashua--handwriting to C:/Users/annch/.cache/huggingface/datasets/AnaChikashua___imagefolder/AnaChikashua--handwriting-2104e8ce1bab6614/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/225M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to C:/Users/annch/.cache/huggingface/datasets/AnaChikashua___imagefolder/AnaChikashua--handwriting-2104e8ce1bab6614/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.

# %%
dataset[0]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=41x44>
